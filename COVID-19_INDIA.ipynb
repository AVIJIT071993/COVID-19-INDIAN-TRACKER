# %% [markdown]
# # State-Wise Cases:

# %%
import pandas as pd

# %%
df = pd.read_html('https://docs.google.com/spreadsheets/d/e/2PACX-1vSc_2y5N0I67wDU38DjDh35IZSIS30rQf7_NYZhtYYGU1jJYT6_kDx4YpF-qw0LSlGsBYP8pqM_a1Pd/pubhtml?urp=gmail_link#')

# %%
df[2]
# Out:
#     Unnamed: 0                   Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          1.0                        State         NaN  Confirmed  Recovered
# 1          2.0                        Total         NaN      11625       1366
# 2          NaN                          NaN         NaN        NaN        NaN
# 3          3.0                  Maharashtra         NaN       2684        259
# 4          4.0                        Delhi         NaN       1561         31
# 5          5.0                   Tamil Nadu         NaN       1204         81
# 6          6.0                    Rajasthan         NaN       1034        147
# 7          7.0               Madhya Pradesh         NaN        741         64
# 8          8.0                Uttar Pradesh         NaN        660         50
# 9          9.0                      Gujarat         NaN        695         59
# 10        10.0                    Telangana         NaN        644        110
# ...

# %%
df[2].drop(["Unnamed: 2","Unnamed: 0"], axis=1, inplace=True)
df[2].drop([1,2], axis=0, inplace=True)

# %%
df[2].to_csv("Corona_India_doc.csv", index=False, header=None)

# %% [markdown]
# # Daily No. of Cases:

# %%
df[5]
# Out:
#     Unnamed: 0   Unnamed: 1       Unnamed: 2       Unnamed: 3  \
# 0          1.0         Date  Daily Confirmed  Total Confirmed
# 1          2.0   30 January                1                1
# 2          NaN          NaN              NaN              NaN
# 3          3.0   31 January                0                1
# 4          4.0  01 February                0                1
# ..         ...          ...              ...              ...
# 73        73.0     10 April              871             7600
# 74        74.0     11 April              854             8454
# 75        75.0     12 April              758             9212
# 76        76.0     13 April             1243            10455
# 77        77.0     14 April             1035            11490
#
#          Unnamed: 4       Unnamed: 5      Unnamed: 6      Unnamed: 7
# 0   Daily Recovered  Total Recovered  Daily Deceased  Total Deceased
# 1                 0                0               0               0
# ...

# %%
df[5].drop(2, axis=0, inplace=True)

# %%
df[5].to_csv("Corona_India_final.csv", index=False, header=None)

# %%
df[5]
# Out:
#     Unnamed: 0   Unnamed: 1       Unnamed: 2       Unnamed: 3  \
# 0          1.0         Date  Daily Confirmed  Total Confirmed
# 1          2.0   30 January                1                1
# 3          3.0   31 January                0                1
# 4          4.0  01 February                0                1
# 5          5.0  02 February                1                2
# ..         ...          ...              ...              ...
# 73        73.0     10 April              871             7600
# 74        74.0     11 April              854             8454
# 75        75.0     12 April              758             9212
# 76        76.0     13 April             1243            10455
# 77        77.0     14 April             1035            11490
#
#          Unnamed: 4       Unnamed: 5      Unnamed: 6      Unnamed: 7
# 0   Daily Recovered  Total Recovered  Daily Deceased  Total Deceased
# 1                 0                0               0               0
# ...

# %% [markdown]
# # No. of test performed per day:

# %%
df[6]
# Out:
#     Unnamed: 0           Unnamed: 1            Unnamed: 2  \
# 0          1.0    Update Time Stamp  Total Samples Tested
# 1          NaN                  NaN                   NaN
# 2          2.0  13/03/2020 00:00:00                  6500
# 3          3.0  18/03/2020 18:00:00                 13125
# 4          4.0  19/03/2020 10:00:00                 13316
# 5          5.0  19/03/2020 18:00:00                 14175
# 6          6.0  20/03/2020 10:00:00                 14376
# 7          7.0  20/03/2020 18:00:00                 15404
# 8          8.0  21/03/2020 10:00:00                 15701
# 9          9.0  21/03/2020 18:00:00                 16911
# 10        10.0  22/03/2020 10:00:00                 16999
# 11        11.0  22/03/2020 18:00:00                 18127
# 12        12.0  23/03/2020 10:00:00                 18383
# 13        13.0  23/03/2020 20:00:00                 20707
# 14        14.0  24/03/2020 10:00:00                 20864
# ...

# %%
df[6].columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
df[6].drop([1,18,19], axis=0, inplace=True)

# %%
df[6].drop(["Unnamed: 6","Unnamed: 7","Unnamed: 5"], axis=1, inplace=True)

# %%
x=[]
for i in df[6]["Unnamed: 1"]:
    i=i.split()
    x.append(i[0])

# %%
z=dict(Date=x)
y=pd.DataFrame(z,index=None)

# %%
df[6].reset_index(drop=True, inplace=True)

# %%
t=pd.DataFrame(df[6], index=None)

# %%
test=pd.concat([t,y],axis=1)
test.reset_index(drop=True)
# Out:
#     Unnamed: 0           Unnamed: 1            Unnamed: 2  \
# 0          1.0    Update Time Stamp  Total Samples Tested
# 1          2.0  13/03/2020 00:00:00                  6500
# 2          3.0  18/03/2020 18:00:00                 13125
# 3          4.0  19/03/2020 10:00:00                 13316
# 4          5.0  19/03/2020 18:00:00                 14175
# 5          6.0  20/03/2020 10:00:00                 14376
# 6          7.0  20/03/2020 18:00:00                 15404
# 7          8.0  21/03/2020 10:00:00                 15701
# 8          9.0  21/03/2020 18:00:00                 16911
# 9         10.0  22/03/2020 10:00:00                 16999
# 10        11.0  22/03/2020 18:00:00                 18127
# 11        12.0  23/03/2020 10:00:00                 18383
# 12        13.0  23/03/2020 20:00:00                 20707
# 13        14.0  24/03/2020 10:00:00                 20864
# 14        15.0  24/03/2020 20:00:00                 22694
# ...

# %%
test.to_csv("Corona_India_tests.csv", index=False, header=None)
